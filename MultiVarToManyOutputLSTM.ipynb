# %% [markdown]
# ## Build Model for S&P500 ETF with Time-Series LSTM
# ### The steps performed include:
# - Load Data from CSV file , we use [Amibroker](https://www.amibroker.com/) exploration to export price and create technical indicator feature such as exponential moving average ,MCD, RSI
# - Preprocess (MinMaxScaler) trand and test data and select features
# - Convert data to window-sequence time-series format  for building LSTC like format of [sample, time steps, features]
# - Build model and feed train data into designed model.
# - Evaluate Model Performancel on the test data using Mean Absolute Error (MAE) and Root MEAN Square Error(RMSE).
# - Predict New Data.

# %% [markdown]
# # Step #1 Load the Data

# %%
# Time Series Forecasting - Multi-output Regression for Stock Market Prediction
# A tutorial for this file is available at www.relataly.com

import math # Mathematical functions 
import numpy as np # Fundamental package for scientific computing with Python
import pandas as pd # Additional functions for analysing and manipulating data
from datetime import date, timedelta, datetime # Date Functions
import time
from pandas.plotting import register_matplotlib_converters # This function adds plotting functions for calender dates
import matplotlib.pyplot as plt # Important package for visualization - we use this to plot the market data
import matplotlib.dates as mdates # Formatting dates

from sklearn.metrics import mean_absolute_error, mean_squared_error # Packages for measuring model performance / errors
from sklearn.preprocessing import RobustScaler, MinMaxScaler # This Scaler removes the median and scales the data according to the quantile range to normalize the price data

import tensorflow as tf
from tensorflow.keras import Sequential # Deep learning library, used for neural networks
from tensorflow.keras.layers import LSTM, Dense, Dropout # Deep learning classes for recurrent and regular densely-connected layers
from tensorflow.keras.callbacks import EarlyStopping # EarlyStopping during model training
from tensorflow.keras import backend
 
    
import seaborn as sns

# %%
# check the tensorflow version and the number of available GPUs
print('Tensorflow Version: ' + tf.__version__)
physical_devices = tf.config.list_physical_devices('GPU')
print("Num GPUs:", len(physical_devices))
# Out:
# Tensorflow Version: 2.11.1
# Num GPUs: 0

# %%
# Load the TensorBoard notebook extension
# %load_ext tensorboard

# !rm -rf ./logs/

# %%
ab_path = "data/QQQ-Daily-Y09-Now.csv"
stockname='QQQ'

start_date='2015-01-01'
end_date='2022-12-31'

date_col='Date'
prediction_col='EMA1'
#feature_cols=['EMA1','SIGNAL','RSI-MA']
feature_cols=['EMA1']

split_way=2

# Week
input_sequence_length =30
output_sequence_length =5
train_ratio=0.1

# Day
# input_sequence_length =60
# output_sequence_length =10
# train_ratio=0.8

epochs =150
batch_size = 32  # 32,48,64
n_early=15  #10/15/20

n_input_neurons=input_sequence_length*2
n_dropout=0.0


main_obj_metric='mean_absolute_error'
main_loss='mean_absolute_error'

option_obj_metric='rmse'  # same name as funtion
def rmse(y_true, y_pred):
 return backend.sqrt(backend.mean(backend.square(y_pred - y_true), axis=-1))

# %%
df=pd.read_csv(f'{ab_path}',parse_dates=['Date/Time'],dayfirst=True)
df.rename(columns={'Date/Time':date_col},inplace=True)
df.drop(columns=['Ticker'],inplace=True)
allCols=list(df.columns)
print(allCols)
# Out:
# ['Date', 'Price', 'EMA1', 'EMA2', 'EMA3', 'MACD', 'SIGNAL', 'RSI', 'RSI-MA']

# %%
df[date_col]=df[date_col].apply( lambda  dx :  datetime(dx.year,dx.month,dx.day ))
df.set_index(date_col,inplace=True)
df=df.loc[start_date:end_date,:]
df=df[feature_cols]
print(df.info())
df.tail()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 2014 entries, 2015-01-02 to 2022-12-30
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   EMA1    2014 non-null   float64
# dtypes: float64(1)
# memory usage: 31.5 KB
# None
#               EMA1
# Date
# 2022-12-23  273.90
# 2022-12-27  272.03
# 2022-12-28  269.86
# 2022-12-29  269.24
# 2022-12-30  268.70

# %% [markdown]
# # Step #2 Exploring the Data

# %%
ncols = 1
nrows = len(feature_cols)

fig, ax = plt.subplots(nrows=nrows, ncols=ncols, sharex=True, figsize=(15, 15))
for i, ax in enumerate(fig.axes):
        sns.lineplot(data = df.iloc[:, i], ax=ax)
        ax.tick_params(axis="x", rotation=30, labelsize=10, length=0)
        ax.xaxis.set_major_locator(mdates.AutoDateLocator())
        ax.title.set_text(df.columns[i])
fig.tight_layout()
plt.show()

# %% [markdown]
# # Step #3 Preprocessing and Feature Selection

# %%
# Indexing Batches
df_train = df.sort_values(by=[date_col]).copy()
df_train.shape
# Out:
# (2014, 1)

# %%
def prepare_data(df):

    # List of considered Features
    FEATURES = feature_cols

    print(f'FEATURE LIST To Predict {prediction_col}')
    print([f for f in FEATURES])

    #Create the dataset with features and filter the data to the list of FEATURES"
    df_filter = df[FEATURES]
    
    print("Convert the data to numpy values")
    np_filter_unscaled = np.array(df_filter)
    np_filter_unscaled = np.reshape(np_filter_unscaled, (df_filter.shape[0], -1))
    print(np_filter_unscaled.shape)
    
    np_c_unscaled = np.array(df[prediction_col]).reshape(-1, 1)
    print(np_c_unscaled.shape)
    
    return np_filter_unscaled, np_c_unscaled

np_filter_unscaled, np_c_unscaled = prepare_data(df_train)   


print("Feature Data",np_filter_unscaled.shape)
print(np_filter_unscaled[:3])
print("Prediction Data",np_c_unscaled.shape)
print(np_c_unscaled[:3])
# Out:
# FEATURE LIST To Predict EMA1
# ['EMA1']
# Convert the data to numpy values
# (2014, 1)
# (2014, 1)
# Feature Data (2014, 1)
# [[103.83]
#  [103.4 ]
#  [102.79]]
# Prediction Data (2014, 1)
# [[103.83]
#  [103.4 ]
#  [102.79]]

# %%
print(f"{input_sequence_length} = Set the input_sequence_length length - this is the timeframe used to make a multiple prediction")
print(f"{output_sequence_length} = The output sequence length is the number of steps that the neural network predicts")

#How much ratio to split
index_Close = df_train.columns.get_loc(prediction_col)
print(f"Prediction Index = {index_Close}")

# As a first step, we get the number of rows to train the model on 80% of the data 
train_data_length = math.ceil(np_filter_unscaled.shape[0] * train_ratio)
print(f"{train_ratio} = {train_data_length} Split the training data into train and train data sets")
# Out:
# 30 = Set the input_sequence_length length - this is the timeframe used to make a multiple prediction
# 5 = The output sequence length is the number of steps that the neural network predicts
# Prediction Index = 0
# 0.1 = 202 Split the training data into train and train data sets

# %%
print("Creating a separate scaler that works on a single column for scaling predictions")
print("Scale each feature to a range between 0 and 1")
scaler_train = MinMaxScaler()
print("Create a separate scaler for a single column")
scaler_pred = MinMaxScaler()


if split_way==1:
    print("Way#1 scale entire data and split data")   
    
    np_scaled = scaler_train.fit_transform(np_filter_unscaled)
    np_scaled_c = scaler_pred.fit_transform(np_c_unscaled)
    
    print("All Data scaled for creating train and test data")    
    print(np_scaled.shape,np_scaled_c.shape)
    print(np_scaled_c[:5],np_scaled_c[:5])
    
    # Create the training and test data
    train_data =np_scaled[0:train_data_length, :]
    test_data = np_scaled[train_data_length - input_sequence_length:, :]

else:
    print("#Way#2 split data and apply  only train to scale")
    
    train_data = np_filter_unscaled[0:train_data_length, :]
    test_data = np_filter_unscaled[train_data_length - input_sequence_length:, :]

    np_PredictVal_unScaled=np_c_unscaled[0:train_data_length]
    
    print("Train Data to be scaled") 
    print(train_data.shape,np_PredictVal_unScaled.shape)
    print(train_data[:5],np_PredictVal_unScaled[:5])
    
    train_data=scaler_train.fit_transform(train_data)
    test_data=scaler_train.transform(test_data)
    
    print(f"For predict test that take the past {input_sequence_length} train value to predict the first test value")
    np_scaled=scaler_train.transform(np_filter_unscaled)
    np_scaled_c = scaler_pred.fit_transform(np_PredictVal_unScaled)
    
    print("Predict val data(Scaled from Train data")
    print(np_scaled_c.shape)
    print(np_scaled_c[:3])
print("=========================================")       
print("Scaled data completely")
print("train and test data")
print(train_data.shape,test_data.shape)
print(train_data[:3])
print(test_data[:3])
# Out:
# Creating a separate scaler that works on a single column for scaling predictions
# Scale each feature to a range between 0 and 1
# Create a separate scaler for a single column
# #Way#2 split data and apply  only train to scale
# Train Data to be scaled
# (202, 1) (202, 1)
# [[103.83]
#  [103.4 ]
#  [102.79]
#  [102.53]
#  [102.67]] [[103.83]
#  [103.4 ]
#  [102.79]
#  [102.53]
#  [102.67]]
# For predict test that take the past 30 train value to predict the first test value
# Predict val data(Scaled from Train data
# (202, 1)
# [[0.23069404]
#  [0.1886608 ]
#  [0.12903226]]
# =========================================
# Scaled data completely
# train and test data
# (202, 1) (1842, 1)
# [[0.23069404]
#  [0.1886608 ]
#  [0.12903226]]
# [[0.24046921]
#  [0.25904203]
#  [0.28445748]]

# %%
print("The RNN needs data with the format of [samples, time steps, features]")
def partition_dataset(input_sequence_length, output_sequence_length, data):
    x, y = [], []
    data_len = data.shape[0]
    for i in range(input_sequence_length, data_len - output_sequence_length):
        x.append(data[i-input_sequence_length:i,:]) #contains input_sequence_length values 0-input_sequence_length * columns
        y.append(data[i:i + output_sequence_length, index_Close]) #contains the prediction values for validation ,  for single-step prediction
    
    # Convert the x and y to numpy arrays
    x = np.array(x)
    y = np.array(y)
    return x, y
# Out:
# The RNN needs data with the format of [samples, time steps, features]

# %%
print(f"Here, we create {len(train_data)} samples, input_sequence_length time steps per sample, and f features")

print("Generate training data and test data")
x_train, y_train = partition_dataset(input_sequence_length, output_sequence_length, train_data)
x_test, y_test = partition_dataset(input_sequence_length, output_sequence_length, test_data)

print("The shapes: the result is: (rows, training_sequence, features) (prediction value, )")
print(x_train.shape, y_train.shape)
print(x_test.shape, y_test.shape)
# Out:
# Here, we create 202 samples, input_sequence_length time steps per sample, and f features
# Generate training data and test data
# The shapes: the result is: (rows, training_sequence, features) (prediction value, )
# (167, 30, 1) (167, 5)
# (1807, 30, 1) (1807, 5)

# %%
print(x_train[:2],y_train[:2])
# Out:
# [[[0.23069404]
#   [0.1886608 ]
#   [0.12903226]
#   [0.10361681]
#   [0.11730205]
#   [0.11632454]
#   [0.09677419]
#   [0.0801564 ]
#   [0.05669599]
#   [0.01368524]
#   [0.        ]
#   [0.00293255]
#   [0.01368524]
#   [0.05669599]
#   [0.09579668]
#   [0.12609971]
#   [0.1026393 ]
#   [0.0742913 ]
#   [0.0684262 ]
#   [0.04887586]
#   [0.04887586]
#   [0.06647116]
#   [0.07917889]
#   [0.10557185]
#   [0.11632454]
#   [0.11827957]
#   [0.14956012]
#   [0.18084066]
#   [0.228739  ]
#   [0.28347996]]
#
#  [[0.1886608 ]
#   [0.12903226]
#   [0.10361681]
#   [0.11730205]
#   [0.11632454]
#   [0.09677419]
#   [0.0801564 ]
#   [0.05669599]
#   [0.01368524]
#   [0.        ]
#   [0.00293255]
#   [0.01368524]
#   [0.05669599]
#   [0.09579668]
#   [0.12609971]
#   [0.1026393 ]
#   [0.0742913 ]
#   [0.0684262 ]
#   [0.04887586]
#   [0.04887586]
#   [0.06647116]
#   [0.07917889]
#   [0.10557185]
#   [0.11632454]
#   [0.11827957]
#   [0.14956012]
#   [0.18084066]
#   [0.228739  ]
#   [0.28347996]
#   [0.33040078]]] [[0.33040078 0.3714565  0.41446725 0.46236559 0.50342131]
#  [0.3714565  0.41446725 0.46236559 0.50342131 0.53861193]]

# %% [markdown]
# # Step #4 Model Training

# %%
# Configure the neural network model
print(f"Train Row : {x_train.shape[0]}")

tf.random.set_seed(7)


n_output_neurons = output_sequence_length
#n_input_neurons=100 # tuned on vpc
      
inputshape_Timestamps= x_train.shape[1]
no_feature=x_train.shape[2]


#n_input_neurons =inputshape_Timestamps * no_feature
print(f"Model with n_neurons = inputshape Timestamps, each with feature variables {inputshape_Timestamps} x {no_feature} = {n_input_neurons} to predict {n_output_neurons}")
# Out:
# Train Row : 167
# Model with n_neurons = inputshape Timestamps, each with feature variables 30 x 1 = 60 to predict 5

# %%
model = Sequential()

model.add(LSTM(n_input_neurons, return_sequences=False, input_shape=(inputshape_Timestamps,no_feature)))

if n_dropout>0:    
    model.add(Dropout(n_dropout)) 

model.add(Dense(n_output_neurons))

# Compile the model

#model.compile(optimizer='adam', loss='mse')
model.compile(optimizer='adam',loss=main_loss,metrics=[main_obj_metric,rmse])
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 60)                14880
#
#  dense (Dense)               (None, 5)                 305
#
# =================================================================
# Total params: 15,185
# Trainable params: 15,185
# Non-trainable params: 0
# _________________________________________________________________

# %%
t_Start=time.time()
print(datetime.now())


early_stop = EarlyStopping(monitor='val_loss', patience=n_early, verbose=1)
# no set early stop due to having best epoch

history = model.fit(x_train, y_train, 
                batch_size=batch_size, 
                epochs=epochs,
                shuffle=False,verbose=2,
                validation_data=(x_test, y_test), 
                callbacks=[early_stop ]   
               )

# log_dir = "logs/fit/" + datetime.now().strftime("%Y%m%d-%H%M%S")
# tensorboard_callback = tf.keras.callbacks.TensorBoard(log_dir=log_dir)

# history = model.fit(x_train, y_train, 
#                 batch_size=batch_size, 
#                 epochs=epochs,
#                 shuffle=False,verbose=0,
#                 validation_data=(x_test, y_test), 
#                 callbacks=[tensorboard_callback,early_stop ]   
#                )

# if n_early==0:

#  history = model.fit(x_train, y_train, 
#                     batch_size=batch_size, 
#                     epochs=epochs,
#                     shuffle=False,
#                     validation_data=(x_test, y_test), 
#                     verbose=2
#                      # ,callbacks=[tensorboard_callback]
#                    )
# else:
#     early_stop = EarlyStopping(monitor='val_loss', patience=n_early, verbose=1)
                    
#     history = model.fit(x_train, y_train, 
#                     batch_size=batch_size, 
#                     epochs=epochs,
#                     shuffle=False,
#                     validation_data=(x_test, y_test),
#                     # verbose=2,callbacks=[early_stop,tensorboard_callback],
#                     verbose=2,callbacks=[early_stop]    
#                    )
        
t_End=time.time()
t_elapsed=(t_End-t_Start)/60/60
print('Total execute making report : ',round(t_elapsed,2)) 
print(datetime.now())
# Out:
# 2023-06-06 22:32:33.139056
# Epoch 1/150
# 6/6 - 7s - loss: 0.5352 - mean_absolute_error: 0.5352 - rmse: 0.5403 - val_loss: 10.5845 - val_mean_absolute_error: 10.5845 - val_rmse: 10.5912 - 7s/epoch - 1s/step
# Epoch 2/150
# 6/6 - 1s - loss: 0.3648 - mean_absolute_error: 0.3648 - rmse: 0.3723 - val_loss: 10.1307 - val_mean_absolute_error: 10.1307 - val_rmse: 10.1388 - 668ms/epoch - 111ms/step
# Epoch 3/150
# 6/6 - 1s - loss: 0.2087 - mean_absolute_error: 0.2087 - rmse: 0.2268 - val_loss: 9.8000 - val_mean_absolute_error: 9.8000 - val_rmse: 9.8094 - 645ms/epoch - 108ms/step
# Epoch 4/150
# 6/6 - 1s - loss: 0.1582 - mean_absolute_error: 0.1582 - rmse: 0.1684 - val_loss: 9.8811 - val_mean_absolute_error: 9.8811 - val_rmse: 9.8859 - 678ms/epoch - 113ms/step
# Epoch 5/150
# 6/6 - 1s - loss: 0.1567 - mean_absolute_error: 0.1567 - rmse: 0.1634 - val_loss: 9.8760 - val_mean_absolute_error: 9.8760 - val_rmse: 9.8806 - 695ms/epoch - 116ms/step
# Epoch 6/150
# 6/6 - 1s - loss: 0.1509 - mean_absolute_error: 0.1509 - rmse: 0.1602 - val_loss: 9.7622 - val_mean_absolute_error: 9.7622 - val_rmse: 9.7668 - 679ms/epoch - 113ms/step
# Epoch 7/150
# 6/6 - 1s - loss: 0.1338 - mean_absolute_error: 0.1338 - rmse: 0.1424 - val_loss: 9.7217 - val_mean_absolute_error: 9.7217 - val_rmse: 9.7261 - 631ms/epoch - 105ms/step
# Epoch 8/150
# 6/6 - 1s - loss: 0.1241 - mean_absolute_error: 0.1241 - rmse: 0.1298 - val_loss: 9.7341 - val_mean_absolute_error: 9.7341 - val_rmse: 9.7389 - 666ms/epoch - 111ms/step
# Epoch 9/150
# 6/6 - 1s - loss: 0.1283 - mean_absolute_error: 0.1283 - rmse: 0.1348 - val_loss: 9.6869 - val_mean_absolute_error: 9.6869 - val_rmse: 9.6920 - 727ms/epoch - 121ms/step
# Epoch 10/150
# 6/6 - 1s - loss: 0.1231 - mean_absolute_error: 0.1231 - rmse: 0.1294 - val_loss: 9.6273 - val_mean_absolute_error: 9.6273 - val_rmse: 9.6324 - 675ms/epoch - 113ms/step
# Epoch 11/150
# 6/6 - 1s - loss: 0.1205 - mean_absolute_error: 0.1205 - rmse: 0.1264 - val_loss: 9.5995 - val_mean_absolute_error: 9.5995 - val_rmse: 9.6046 - 654ms/epoch - 109ms/step
# Epoch 12/150
# 6/6 - 1s - loss: 0.1192 - mean_absolute_error: 0.1192 - rmse: 0.1252 - val_loss: 9.5621 - val_mean_absolute_error: 9.5621 - val_rmse: 9.5677 - 623ms/epoch - 104ms/step
# Epoch 13/150
# 6/6 - 1s - loss: 0.1178 - mean_absolute_error: 0.1178 - rmse: 0.1236 - val_loss: 9.5096 - val_mean_absolute_error: 9.5096 - val_rmse: 9.5158 - 655ms/epoch - 109ms/step
# Epoch 14/150
# 6/6 - 1s - loss: 0.1158 - mean_absolute_error: 0.1158 - rmse: 0.1216 - val_loss: 9.4701 - val_mean_absolute_error: 9.4701 - val_rmse: 9.4770 - 637ms/epoch - 106ms/step
# Epoch 15/150
# 6/6 - 1s - loss: 0.1148 - mean_absolute_error: 0.1148 - rmse: 0.1206 - val_loss: 9.4250 - val_mean_absolute_error: 9.4250 - val_rmse: 9.4325 - 610ms/epoch - 102ms/step
# Epoch 16/150
# 6/6 - 1s - loss: 0.1135 - mean_absolute_error: 0.1135 - rmse: 0.1192 - val_loss: 9.3819 - val_mean_absolute_error: 9.3819 - val_rmse: 9.3901 - 708ms/epoch - 118ms/step
# Epoch 17/150
# 6/6 - 1s - loss: 0.1124 - mean_absolute_error: 0.1124 - rmse: 0.1181 - val_loss: 9.3423 - val_mean_absolute_error: 9.3423 - val_rmse: 9.3513 - 690ms/epoch - 115ms/step
# Epoch 18/150
# 6/6 - 1s - loss: 0.1113 - mean_absolute_error: 0.1113 - rmse: 0.1170 - val_loss: 9.2986 - val_mean_absolute_error: 9.2986 - val_rmse: 9.3085 - 655ms/epoch - 109ms/step
# Epoch 19/150
# 6/6 - 1s - loss: 0.1101 - mean_absolute_error: 0.1101 - rmse: 0.1158 - val_loss: 9.2554 - val_mean_absolute_error: 9.2554 - val_rmse: 9.2659 - 631ms/epoch - 105ms/step
# Epoch 20/150
# 6/6 - 1s - loss: 0.1093 - mean_absolute_error: 0.1093 - rmse: 0.1148 - val_loss: 9.2084 - val_mean_absolute_error: 9.2084 - val_rmse: 9.2199 - 870ms/epoch - 145ms/step
# Epoch 21/150
# 6/6 - 1s - loss: 0.1081 - mean_absolute_error: 0.1081 - rmse: 0.1137 - val_loss: 9.1637 - val_mean_absolute_error: 9.1637 - val_rmse: 9.1763 - 969ms/epoch - 161ms/step
# Epoch 22/150
# 6/6 - 1s - loss: 0.1073 - mean_absolute_error: 0.1073 - rmse: 0.1129 - val_loss: 9.1172 - val_mean_absolute_error: 9.1172 - val_rmse: 9.1309 - 1s/epoch - 175ms/step
# Epoch 23/150
# 6/6 - 1s - loss: 0.1061 - mean_absolute_error: 0.1061 - rmse: 0.1117 - val_loss: 9.0703 - val_mean_absolute_error: 9.0703 - val_rmse: 9.0849 - 954ms/epoch - 159ms/step
# Epoch 24/150
# 6/6 - 1s - loss: 0.1053 - mean_absolute_error: 0.1053 - rmse: 0.1108 - val_loss: 9.0216 - val_mean_absolute_error: 9.0216 - val_rmse: 9.0373 - 766ms/epoch - 128ms/step
# Epoch 25/150
# 6/6 - 1s - loss: 0.1043 - mean_absolute_error: 0.1043 - rmse: 0.1099 - val_loss: 8.9677 - val_mean_absolute_error: 8.9677 - val_rmse: 8.9851 - 798ms/epoch - 133ms/step
# Epoch 26/150
# 6/6 - 1s - loss: 0.1032 - mean_absolute_error: 0.1032 - rmse: 0.1090 - val_loss: 8.9124 - val_mean_absolute_error: 8.9124 - val_rmse: 8.9306 - 719ms/epoch - 120ms/step
# Epoch 27/150
# 6/6 - 1s - loss: 0.1024 - mean_absolute_error: 0.1024 - rmse: 0.1081 - val_loss: 8.8518 - val_mean_absolute_error: 8.8518 - val_rmse: 8.8709 - 635ms/epoch - 106ms/step
# Epoch 28/150
# 6/6 - 1s - loss: 0.1013 - mean_absolute_error: 0.1013 - rmse: 0.1070 - val_loss: 8.7935 - val_mean_absolute_error: 8.7935 - val_rmse: 8.8139 - 740ms/epoch - 123ms/step
# Epoch 29/150
# 6/6 - 1s - loss: 0.1004 - mean_absolute_error: 0.1004 - rmse: 0.1061 - val_loss: 8.7323 - val_mean_absolute_error: 8.7323 - val_rmse: 8.7547 - 702ms/epoch - 117ms/step
# Epoch 30/150
# 6/6 - 1s - loss: 0.0994 - mean_absolute_error: 0.0994 - rmse: 0.1053 - val_loss: 8.6698 - val_mean_absolute_error: 8.6698 - val_rmse: 8.6942 - 794ms/epoch - 132ms/step
# Epoch 31/150
# 6/6 - 1s - loss: 0.0984 - mean_absolute_error: 0.0984 - rmse: 0.1044 - val_loss: 8.6107 - val_mean_absolute_error: 8.6107 - val_rmse: 8.6363 - 923ms/epoch - 154ms/step
# Epoch 32/150
# 6/6 - 1s - loss: 0.0977 - mean_absolute_error: 0.0977 - rmse: 0.1037 - val_loss: 8.5511 - val_mean_absolute_error: 8.5511 - val_rmse: 8.5783 - 1s/epoch - 174ms/step
# Epoch 33/150
# 6/6 - 1s - loss: 0.0969 - mean_absolute_error: 0.0969 - rmse: 0.1030 - val_loss: 8.4935 - val_mean_absolute_error: 8.4935 - val_rmse: 8.5224 - 1s/epoch - 171ms/step
# Epoch 34/150
# 6/6 - 1s - loss: 0.0961 - mean_absolute_error: 0.0961 - rmse: 0.1022 - val_loss: 8.4380 - val_mean_absolute_error: 8.4380 - val_rmse: 8.4681 - 1s/epoch - 201ms/step
# Epoch 35/150
# 6/6 - 1s - loss: 0.0955 - mean_absolute_error: 0.0955 - rmse: 0.1014 - val_loss: 8.3862 - val_mean_absolute_error: 8.3862 - val_rmse: 8.4175 - 1s/epoch - 168ms/step
# Epoch 36/150
# 6/6 - 1s - loss: 0.0948 - mean_absolute_error: 0.0948 - rmse: 0.1008 - val_loss: 8.3389 - val_mean_absolute_error: 8.3389 - val_rmse: 8.3720 - 989ms/epoch - 165ms/step
# Epoch 37/150
# 6/6 - 1s - loss: 0.0941 - mean_absolute_error: 0.0941 - rmse: 0.1002 - val_loss: 8.2979 - val_mean_absolute_error: 8.2979 - val_rmse: 8.3318 - 905ms/epoch - 151ms/step
# Epoch 38/150
# 6/6 - 1s - loss: 0.0935 - mean_absolute_error: 0.0935 - rmse: 0.0995 - val_loss: 8.2531 - val_mean_absolute_error: 8.2531 - val_rmse: 8.2889 - 849ms/epoch - 142ms/step
# Epoch 39/150
# 6/6 - 1s - loss: 0.0928 - mean_absolute_error: 0.0928 - rmse: 0.0990 - val_loss: 8.2135 - val_mean_absolute_error: 8.2135 - val_rmse: 8.2503 - 834ms/epoch - 139ms/step
# Epoch 40/150
# 6/6 - 1s - loss: 0.0923 - mean_absolute_error: 0.0923 - rmse: 0.0984 - val_loss: 8.1722 - val_mean_absolute_error: 8.1722 - val_rmse: 8.2105 - 786ms/epoch - 131ms/step
# Epoch 41/150
# 6/6 - 1s - loss: 0.0915 - mean_absolute_error: 0.0915 - rmse: 0.0978 - val_loss: 8.1413 - val_mean_absolute_error: 8.1413 - val_rmse: 8.1792 - 635ms/epoch - 106ms/step
# Epoch 42/150
# 6/6 - 1s - loss: 0.0913 - mean_absolute_error: 0.0913 - rmse: 0.0972 - val_loss: 8.1001 - val_mean_absolute_error: 8.1001 - val_rmse: 8.1405 - 601ms/epoch - 100ms/step
# Epoch 43/150
# 6/6 - 1s - loss: 0.0903 - mean_absolute_error: 0.0903 - rmse: 0.0966 - val_loss: 8.0716 - val_mean_absolute_error: 8.0716 - val_rmse: 8.1112 - 605ms/epoch - 101ms/step
# Epoch 44/150
# 6/6 - 1s - loss: 0.0904 - mean_absolute_error: 0.0904 - rmse: 0.0965 - val_loss: 8.0322 - val_mean_absolute_error: 8.0322 - val_rmse: 8.0744 - 603ms/epoch - 101ms/step
# Epoch 45/150
# 6/6 - 1s - loss: 0.0893 - mean_absolute_error: 0.0893 - rmse: 0.0959 - val_loss: 8.0118 - val_mean_absolute_error: 8.0118 - val_rmse: 8.0520 - 594ms/epoch - 99ms/step
# Epoch 46/150
# 6/6 - 1s - loss: 0.0894 - mean_absolute_error: 0.0894 - rmse: 0.0955 - val_loss: 7.9764 - val_mean_absolute_error: 7.9764 - val_rmse: 8.0181 - 666ms/epoch - 111ms/step
# Epoch 47/150
# 6/6 - 1s - loss: 0.0884 - mean_absolute_error: 0.0884 - rmse: 0.0948 - val_loss: 7.9486 - val_mean_absolute_error: 7.9486 - val_rmse: 7.9900 - 682ms/epoch - 114ms/step
# Epoch 48/150
# 6/6 - 1s - loss: 0.0881 - mean_absolute_error: 0.0881 - rmse: 0.0942 - val_loss: 7.9221 - val_mean_absolute_error: 7.9221 - val_rmse: 7.9636 - 665ms/epoch - 111ms/step
# Epoch 49/150
# 6/6 - 1s - loss: 0.0873 - mean_absolute_error: 0.0873 - rmse: 0.0936 - val_loss: 7.8965 - val_mean_absolute_error: 7.8965 - val_rmse: 7.9375 - 719ms/epoch - 120ms/step
# Epoch 50/150
# 6/6 - 1s - loss: 0.0869 - mean_absolute_error: 0.0869 - rmse: 0.0932 - val_loss: 7.8693 - val_mean_absolute_error: 7.8693 - val_rmse: 7.9115 - 995ms/epoch - 166ms/step
# Epoch 51/150
# 6/6 - 1s - loss: 0.0862 - mean_absolute_error: 0.0862 - rmse: 0.0928 - val_loss: 7.8522 - val_mean_absolute_error: 7.8522 - val_rmse: 7.8929 - 1s/epoch - 193ms/step
# Epoch 52/150
# 6/6 - 1s - loss: 0.0860 - mean_absolute_error: 0.0860 - rmse: 0.0920 - val_loss: 7.8211 - val_mean_absolute_error: 7.8211 - val_rmse: 7.8629 - 1s/epoch - 195ms/step
# Epoch 53/150
# 6/6 - 1s - loss: 0.0849 - mean_absolute_error: 0.0849 - rmse: 0.0914 - val_loss: 7.7995 - val_mean_absolute_error: 7.7995 - val_rmse: 7.8397 - 1s/epoch - 197ms/step
# Epoch 54/150
# 6/6 - 1s - loss: 0.0845 - mean_absolute_error: 0.0845 - rmse: 0.0909 - val_loss: 7.7784 - val_mean_absolute_error: 7.7784 - val_rmse: 7.8197 - 974ms/epoch - 162ms/step
# Epoch 55/150
# 6/6 - 1s - loss: 0.0841 - mean_absolute_error: 0.0841 - rmse: 0.0907 - val_loss: 7.7573 - val_mean_absolute_error: 7.7573 - val_rmse: 7.7958 - 724ms/epoch - 121ms/step
# Epoch 56/150
# 6/6 - 1s - loss: 0.0836 - mean_absolute_error: 0.0836 - rmse: 0.0901 - val_loss: 7.7332 - val_mean_absolute_error: 7.7332 - val_rmse: 7.7741 - 632ms/epoch - 105ms/step
# Epoch 57/150
# 6/6 - 1s - loss: 0.0834 - mean_absolute_error: 0.0834 - rmse: 0.0902 - val_loss: 7.7192 - val_mean_absolute_error: 7.7192 - val_rmse: 7.7560 - 591ms/epoch - 99ms/step
# Epoch 58/150
# 6/6 - 1s - loss: 0.0829 - mean_absolute_error: 0.0829 - rmse: 0.0891 - val_loss: 7.6795 - val_mean_absolute_error: 7.6795 - val_rmse: 7.7211 - 591ms/epoch - 99ms/step
# Epoch 59/150
# 6/6 - 1s - loss: 0.0816 - mean_absolute_error: 0.0816 - rmse: 0.0889 - val_loss: 7.6931 - val_mean_absolute_error: 7.6931 - val_rmse: 7.7268 - 662ms/epoch - 110ms/step
# Epoch 60/150
# 6/6 - 1s - loss: 0.0849 - mean_absolute_error: 0.0849 - rmse: 0.0915 - val_loss: 7.6349 - val_mean_absolute_error: 7.6349 - val_rmse: 7.6748 - 776ms/epoch - 129ms/step
# Epoch 61/150
# 6/6 - 1s - loss: 0.0811 - mean_absolute_error: 0.0811 - rmse: 0.0880 - val_loss: 7.6627 - val_mean_absolute_error: 7.6627 - val_rmse: 7.6943 - 700ms/epoch - 117ms/step
# Epoch 62/150
# 6/6 - 1s - loss: 0.0858 - mean_absolute_error: 0.0858 - rmse: 0.0921 - val_loss: 7.6154 - val_mean_absolute_error: 7.6154 - val_rmse: 7.6505 - 691ms/epoch - 115ms/step
# Epoch 63/150
# 6/6 - 1s - loss: 0.0795 - mean_absolute_error: 0.0795 - rmse: 0.0859 - val_loss: 7.6044 - val_mean_absolute_error: 7.6044 - val_rmse: 7.6377 - 639ms/epoch - 107ms/step
# Epoch 64/150
# 6/6 - 1s - loss: 0.0813 - mean_absolute_error: 0.0813 - rmse: 0.0878 - val_loss: 7.5703 - val_mean_absolute_error: 7.5703 - val_rmse: 7.6048 - 684ms/epoch - 114ms/step
# Epoch 65/150
# 6/6 - 1s - loss: 0.0782 - mean_absolute_error: 0.0782 - rmse: 0.0845 - val_loss: 7.5794 - val_mean_absolute_error: 7.5794 - val_rmse: 7.6123 - 825ms/epoch - 138ms/step
# Epoch 66/150
# 6/6 - 1s - loss: 0.0801 - mean_absolute_error: 0.0801 - rmse: 0.0863 - val_loss: 7.5472 - val_mean_absolute_error: 7.5472 - val_rmse: 7.5854 - 736ms/epoch - 123ms/step
# Epoch 67/150
# 6/6 - 1s - loss: 0.0786 - mean_absolute_error: 0.0786 - rmse: 0.0861 - val_loss: 7.5543 - val_mean_absolute_error: 7.5543 - val_rmse: 7.5828 - 690ms/epoch - 115ms/step
# Epoch 68/150
# 6/6 - 1s - loss: 0.0843 - mean_absolute_error: 0.0843 - rmse: 0.0923 - val_loss: 7.5211 - val_mean_absolute_error: 7.5211 - val_rmse: 7.5511 - 762ms/epoch - 127ms/step
# Epoch 69/150
# 6/6 - 1s - loss: 0.0774 - mean_absolute_error: 0.0774 - rmse: 0.0842 - val_loss: 7.4831 - val_mean_absolute_error: 7.4831 - val_rmse: 7.5173 - 648ms/epoch - 108ms/step
# Epoch 70/150
# 6/6 - 1s - loss: 0.0761 - mean_absolute_error: 0.0761 - rmse: 0.0829 - val_loss: 7.4784 - val_mean_absolute_error: 7.4784 - val_rmse: 7.5095 - 602ms/epoch - 100ms/step
# Epoch 71/150
# 6/6 - 1s - loss: 0.0752 - mean_absolute_error: 0.0752 - rmse: 0.0816 - val_loss: 7.4541 - val_mean_absolute_error: 7.4541 - val_rmse: 7.4854 - 655ms/epoch - 109ms/step
# Epoch 72/150
# 6/6 - 1s - loss: 0.0738 - mean_absolute_error: 0.0738 - rmse: 0.0803 - val_loss: 7.4449 - val_mean_absolute_error: 7.4449 - val_rmse: 7.4744 - 727ms/epoch - 121ms/step
# Epoch 73/150
# 6/6 - 1s - loss: 0.0741 - mean_absolute_error: 0.0741 - rmse: 0.0804 - val_loss: 7.4197 - val_mean_absolute_error: 7.4197 - val_rmse: 7.4517 - 630ms/epoch - 105ms/step
# Epoch 74/150
# 6/6 - 1s - loss: 0.0733 - mean_absolute_error: 0.0733 - rmse: 0.0797 - val_loss: 7.4264 - val_mean_absolute_error: 7.4264 - val_rmse: 7.4561 - 655ms/epoch - 109ms/step
# Epoch 75/150
# 6/6 - 1s - loss: 0.0738 - mean_absolute_error: 0.0738 - rmse: 0.0799 - val_loss: 7.3845 - val_mean_absolute_error: 7.3845 - val_rmse: 7.4176 - 653ms/epoch - 109ms/step
# Epoch 76/150
# 6/6 - 1s - loss: 0.0746 - mean_absolute_error: 0.0746 - rmse: 0.0809 - val_loss: 7.4018 - val_mean_absolute_error: 7.4018 - val_rmse: 7.4330 - 687ms/epoch - 114ms/step
# Epoch 77/150
# 6/6 - 1s - loss: 0.0738 - mean_absolute_error: 0.0738 - rmse: 0.0802 - val_loss: 7.3633 - val_mean_absolute_error: 7.3633 - val_rmse: 7.3969 - 689ms/epoch - 115ms/step
# Epoch 78/150
# 6/6 - 1s - loss: 0.0729 - mean_absolute_error: 0.0729 - rmse: 0.0791 - val_loss: 7.3889 - val_mean_absolute_error: 7.3889 - val_rmse: 7.4183 - 758ms/epoch - 126ms/step
# Epoch 79/150
# 6/6 - 1s - loss: 0.0771 - mean_absolute_error: 0.0771 - rmse: 0.0832 - val_loss: 7.3429 - val_mean_absolute_error: 7.3429 - val_rmse: 7.3761 - 711ms/epoch - 119ms/step
# Epoch 80/150
# 6/6 - 1s - loss: 0.0768 - mean_absolute_error: 0.0768 - rmse: 0.0840 - val_loss: 7.3120 - val_mean_absolute_error: 7.3120 - val_rmse: 7.3511 - 663ms/epoch - 111ms/step
# Epoch 81/150
# 6/6 - 1s - loss: 0.0760 - mean_absolute_error: 0.0760 - rmse: 0.0821 - val_loss: 7.2966 - val_mean_absolute_error: 7.2966 - val_rmse: 7.3392 - 640ms/epoch - 107ms/step
# Epoch 82/150
# 6/6 - 1s - loss: 0.0726 - mean_absolute_error: 0.0726 - rmse: 0.0810 - val_loss: 7.3342 - val_mean_absolute_error: 7.3342 - val_rmse: 7.3619 - 568ms/epoch - 95ms/step
# Epoch 83/150
# 6/6 - 1s - loss: 0.0774 - mean_absolute_error: 0.0774 - rmse: 0.0850 - val_loss: 7.2886 - val_mean_absolute_error: 7.2886 - val_rmse: 7.3213 - 568ms/epoch - 95ms/step
# Epoch 84/150
# 6/6 - 1s - loss: 0.0715 - mean_absolute_error: 0.0715 - rmse: 0.0782 - val_loss: 7.2958 - val_mean_absolute_error: 7.2958 - val_rmse: 7.3264 - 546ms/epoch - 91ms/step
# Epoch 85/150
# 6/6 - 1s - loss: 0.0717 - mean_absolute_error: 0.0717 - rmse: 0.0781 - val_loss: 7.2793 - val_mean_absolute_error: 7.2793 - val_rmse: 7.3120 - 624ms/epoch - 104ms/step
# Epoch 86/150
# 6/6 - 1s - loss: 0.0703 - mean_absolute_error: 0.0703 - rmse: 0.0775 - val_loss: 7.2833 - val_mean_absolute_error: 7.2833 - val_rmse: 7.3129 - 568ms/epoch - 95ms/step
# Epoch 87/150
# 6/6 - 1s - loss: 0.0702 - mean_absolute_error: 0.0702 - rmse: 0.0768 - val_loss: 7.2610 - val_mean_absolute_error: 7.2610 - val_rmse: 7.2914 - 537ms/epoch - 90ms/step
# Epoch 88/150
# 6/6 - 1s - loss: 0.0704 - mean_absolute_error: 0.0704 - rmse: 0.0772 - val_loss: 7.2746 - val_mean_absolute_error: 7.2746 - val_rmse: 7.3046 - 603ms/epoch - 101ms/step
# Epoch 89/150
# 6/6 - 1s - loss: 0.0709 - mean_absolute_error: 0.0709 - rmse: 0.0775 - val_loss: 7.2412 - val_mean_absolute_error: 7.2412 - val_rmse: 7.2722 - 608ms/epoch - 101ms/step
# Epoch 90/150
# 6/6 - 1s - loss: 0.0738 - mean_absolute_error: 0.0738 - rmse: 0.0802 - val_loss: 7.2243 - val_mean_absolute_error: 7.2243 - val_rmse: 7.2593 - 643ms/epoch - 107ms/step
# Epoch 91/150
# 6/6 - 1s - loss: 0.0735 - mean_absolute_error: 0.0735 - rmse: 0.0799 - val_loss: 7.2140 - val_mean_absolute_error: 7.2140 - val_rmse: 7.2497 - 619ms/epoch - 103ms/step
# Epoch 92/150
# 6/6 - 1s - loss: 0.0737 - mean_absolute_error: 0.0737 - rmse: 0.0812 - val_loss: 7.2092 - val_mean_absolute_error: 7.2092 - val_rmse: 7.2365 - 784ms/epoch - 131ms/step
# Epoch 93/150
# 6/6 - 1s - loss: 0.0763 - mean_absolute_error: 0.0763 - rmse: 0.0841 - val_loss: 7.1720 - val_mean_absolute_error: 7.1720 - val_rmse: 7.2090 - 690ms/epoch - 115ms/step
# Epoch 94/150
# 6/6 - 1s - loss: 0.0734 - mean_absolute_error: 0.0734 - rmse: 0.0807 - val_loss: 7.1871 - val_mean_absolute_error: 7.1871 - val_rmse: 7.2242 - 867ms/epoch - 145ms/step
# Epoch 95/150
# 6/6 - 1s - loss: 0.0712 - mean_absolute_error: 0.0712 - rmse: 0.0773 - val_loss: 7.1696 - val_mean_absolute_error: 7.1696 - val_rmse: 7.2019 - 926ms/epoch - 154ms/step
# Epoch 96/150
# 6/6 - 1s - loss: 0.0675 - mean_absolute_error: 0.0675 - rmse: 0.0739 - val_loss: 7.1713 - val_mean_absolute_error: 7.1713 - val_rmse: 7.2001 - 692ms/epoch - 115ms/step
# Epoch 97/150
# 6/6 - 1s - loss: 0.0710 - mean_absolute_error: 0.0710 - rmse: 0.0775 - val_loss: 7.1481 - val_mean_absolute_error: 7.1481 - val_rmse: 7.1775 - 648ms/epoch - 108ms/step
# Epoch 98/150
# 6/6 - 1s - loss: 0.0696 - mean_absolute_error: 0.0696 - rmse: 0.0769 - val_loss: 7.1648 - val_mean_absolute_error: 7.1648 - val_rmse: 7.1944 - 586ms/epoch - 98ms/step
# Epoch 99/150
# 6/6 - 1s - loss: 0.0693 - mean_absolute_error: 0.0693 - rmse: 0.0755 - val_loss: 7.1447 - val_mean_absolute_error: 7.1447 - val_rmse: 7.1777 - 621ms/epoch - 104ms/step
# Epoch 100/150
# 6/6 - 1s - loss: 0.0674 - mean_absolute_error: 0.0674 - rmse: 0.0744 - val_loss: 7.1576 - val_mean_absolute_error: 7.1576 - val_rmse: 7.1843 - 601ms/epoch - 100ms/step
# Epoch 101/150
# 6/6 - 1s - loss: 0.0692 - mean_absolute_error: 0.0692 - rmse: 0.0752 - val_loss: 7.1274 - val_mean_absolute_error: 7.1274 - val_rmse: 7.1544 - 583ms/epoch - 97ms/step
# Epoch 102/150
# 6/6 - 1s - loss: 0.0665 - mean_absolute_error: 0.0665 - rmse: 0.0730 - val_loss: 7.1406 - val_mean_absolute_error: 7.1406 - val_rmse: 7.1672 - 597ms/epoch - 100ms/step
# Epoch 103/150
# 6/6 - 1s - loss: 0.0669 - mean_absolute_error: 0.0669 - rmse: 0.0730 - val_loss: 7.1121 - val_mean_absolute_error: 7.1121 - val_rmse: 7.1403 - 573ms/epoch - 96ms/step
# Epoch 104/150
# 6/6 - 1s - loss: 0.0659 - mean_absolute_error: 0.0659 - rmse: 0.0723 - val_loss: 7.1399 - val_mean_absolute_error: 7.1399 - val_rmse: 7.1659 - 574ms/epoch - 96ms/step
# Epoch 105/150
# 6/6 - 1s - loss: 0.0689 - mean_absolute_error: 0.0689 - rmse: 0.0748 - val_loss: 7.1060 - val_mean_absolute_error: 7.1060 - val_rmse: 7.1353 - 591ms/epoch - 99ms/step
# Epoch 106/150
# 6/6 - 1s - loss: 0.0690 - mean_absolute_error: 0.0690 - rmse: 0.0753 - val_loss: 7.1276 - val_mean_absolute_error: 7.1276 - val_rmse: 7.1554 - 574ms/epoch - 96ms/step
# Epoch 107/150
# 6/6 - 1s - loss: 0.0688 - mean_absolute_error: 0.0688 - rmse: 0.0746 - val_loss: 7.0969 - val_mean_absolute_error: 7.0969 - val_rmse: 7.1268 - 584ms/epoch - 97ms/step
# Epoch 108/150
# 6/6 - 1s - loss: 0.0692 - mean_absolute_error: 0.0692 - rmse: 0.0757 - val_loss: 7.0875 - val_mean_absolute_error: 7.0875 - val_rmse: 7.1123 - 542ms/epoch - 90ms/step
# Epoch 109/150
# 6/6 - 1s - loss: 0.0739 - mean_absolute_error: 0.0739 - rmse: 0.0810 - val_loss: 7.0577 - val_mean_absolute_error: 7.0577 - val_rmse: 7.0900 - 538ms/epoch - 90ms/step
# Epoch 110/150
# 6/6 - 1s - loss: 0.0721 - mean_absolute_error: 0.0721 - rmse: 0.0790 - val_loss: 7.0523 - val_mean_absolute_error: 7.0523 - val_rmse: 7.0848 - 526ms/epoch - 88ms/step
# Epoch 111/150
# 6/6 - 1s - loss: 0.0689 - mean_absolute_error: 0.0689 - rmse: 0.0750 - val_loss: 7.0571 - val_mean_absolute_error: 7.0571 - val_rmse: 7.0880 - 582ms/epoch - 97ms/step
# Epoch 112/150
# 6/6 - 1s - loss: 0.0658 - mean_absolute_error: 0.0658 - rmse: 0.0720 - val_loss: 7.0559 - val_mean_absolute_error: 7.0559 - val_rmse: 7.0860 - 535ms/epoch - 89ms/step
# Epoch 113/150
# 6/6 - 1s - loss: 0.0670 - mean_absolute_error: 0.0670 - rmse: 0.0737 - val_loss: 7.0307 - val_mean_absolute_error: 7.0307 - val_rmse: 7.0586 - 522ms/epoch - 87ms/step
# Epoch 114/150
# 6/6 - 1s - loss: 0.0660 - mean_absolute_error: 0.0660 - rmse: 0.0725 - val_loss: 7.0412 - val_mean_absolute_error: 7.0412 - val_rmse: 7.0682 - 513ms/epoch - 86ms/step
# Epoch 115/150
# 6/6 - 1s - loss: 0.0654 - mean_absolute_error: 0.0654 - rmse: 0.0717 - val_loss: 7.0288 - val_mean_absolute_error: 7.0288 - val_rmse: 7.0580 - 548ms/epoch - 91ms/step
# Epoch 116/150
# 6/6 - 1s - loss: 0.0645 - mean_absolute_error: 0.0645 - rmse: 0.0711 - val_loss: 7.0339 - val_mean_absolute_error: 7.0339 - val_rmse: 7.0577 - 530ms/epoch - 88ms/step
# Epoch 117/150
# 6/6 - 1s - loss: 0.0656 - mean_absolute_error: 0.0656 - rmse: 0.0724 - val_loss: 7.0235 - val_mean_absolute_error: 7.0235 - val_rmse: 7.0508 - 557ms/epoch - 93ms/step
# Epoch 118/150
# 6/6 - 1s - loss: 0.0652 - mean_absolute_error: 0.0652 - rmse: 0.0718 - val_loss: 7.0360 - val_mean_absolute_error: 7.0360 - val_rmse: 7.0613 - 524ms/epoch - 87ms/step
# Epoch 119/150
# 6/6 - 1s - loss: 0.0649 - mean_absolute_error: 0.0649 - rmse: 0.0710 - val_loss: 7.0202 - val_mean_absolute_error: 7.0202 - val_rmse: 7.0459 - 535ms/epoch - 89ms/step
# Epoch 120/150
# 6/6 - 1s - loss: 0.0644 - mean_absolute_error: 0.0644 - rmse: 0.0707 - val_loss: 7.0226 - val_mean_absolute_error: 7.0226 - val_rmse: 7.0482 - 524ms/epoch - 87ms/step
# Epoch 121/150
# 6/6 - 1s - loss: 0.0656 - mean_absolute_error: 0.0656 - rmse: 0.0723 - val_loss: 7.0264 - val_mean_absolute_error: 7.0264 - val_rmse: 7.0532 - 514ms/epoch - 86ms/step
# Epoch 122/150
# 6/6 - 1s - loss: 0.0641 - mean_absolute_error: 0.0641 - rmse: 0.0704 - val_loss: 7.0176 - val_mean_absolute_error: 7.0176 - val_rmse: 7.0449 - 516ms/epoch - 86ms/step
# Epoch 123/150
# 6/6 - 1s - loss: 0.0629 - mean_absolute_error: 0.0629 - rmse: 0.0693 - val_loss: 7.0230 - val_mean_absolute_error: 7.0230 - val_rmse: 7.0491 - 586ms/epoch - 98ms/step
# Epoch 124/150
# 6/6 - 1s - loss: 0.0637 - mean_absolute_error: 0.0637 - rmse: 0.0699 - val_loss: 6.9893 - val_mean_absolute_error: 6.9893 - val_rmse: 7.0163 - 550ms/epoch - 92ms/step
# Epoch 125/150
# 6/6 - 1s - loss: 0.0677 - mean_absolute_error: 0.0677 - rmse: 0.0745 - val_loss: 7.0235 - val_mean_absolute_error: 7.0235 - val_rmse: 7.0497 - 537ms/epoch - 90ms/step
# Epoch 126/150
# 6/6 - 1s - loss: 0.0673 - mean_absolute_error: 0.0673 - rmse: 0.0730 - val_loss: 6.9735 - val_mean_absolute_error: 6.9735 - val_rmse: 7.0050 - 519ms/epoch - 87ms/step
# Epoch 127/150
# 6/6 - 1s - loss: 0.0652 - mean_absolute_error: 0.0652 - rmse: 0.0714 - val_loss: 7.0134 - val_mean_absolute_error: 7.0134 - val_rmse: 7.0388 - 550ms/epoch - 92ms/step
# Epoch 128/150
# 6/6 - 1s - loss: 0.0651 - mean_absolute_error: 0.0651 - rmse: 0.0708 - val_loss: 6.9539 - val_mean_absolute_error: 6.9539 - val_rmse: 6.9838 - 540ms/epoch - 90ms/step
# Epoch 129/150
# 6/6 - 1s - loss: 0.0666 - mean_absolute_error: 0.0666 - rmse: 0.0732 - val_loss: 7.0179 - val_mean_absolute_error: 7.0179 - val_rmse: 7.0440 - 659ms/epoch - 110ms/step
# Epoch 130/150
# 6/6 - 1s - loss: 0.0735 - mean_absolute_error: 0.0735 - rmse: 0.0794 - val_loss: 6.9689 - val_mean_absolute_error: 6.9689 - val_rmse: 6.9993 - 592ms/epoch - 99ms/step
# Epoch 131/150
# 6/6 - 1s - loss: 0.0701 - mean_absolute_error: 0.0701 - rmse: 0.0766 - val_loss: 6.9456 - val_mean_absolute_error: 6.9456 - val_rmse: 6.9784 - 547ms/epoch - 91ms/step
# Epoch 132/150
# 6/6 - 1s - loss: 0.0746 - mean_absolute_error: 0.0746 - rmse: 0.0807 - val_loss: 6.9184 - val_mean_absolute_error: 6.9184 - val_rmse: 6.9528 - 554ms/epoch - 92ms/step
# Epoch 133/150
# 6/6 - 1s - loss: 0.0644 - mean_absolute_error: 0.0644 - rmse: 0.0708 - val_loss: 6.9815 - val_mean_absolute_error: 6.9815 - val_rmse: 7.0074 - 527ms/epoch - 88ms/step
# Epoch 134/150
# 6/6 - 1s - loss: 0.0691 - mean_absolute_error: 0.0691 - rmse: 0.0749 - val_loss: 6.9200 - val_mean_absolute_error: 6.9200 - val_rmse: 6.9483 - 513ms/epoch - 86ms/step
# Epoch 135/150
# 6/6 - 1s - loss: 0.0660 - mean_absolute_error: 0.0660 - rmse: 0.0724 - val_loss: 6.9346 - val_mean_absolute_error: 6.9346 - val_rmse: 6.9596 - 528ms/epoch - 88ms/step
# Epoch 136/150
# 6/6 - 1s - loss: 0.0649 - mean_absolute_error: 0.0649 - rmse: 0.0710 - val_loss: 6.9303 - val_mean_absolute_error: 6.9303 - val_rmse: 6.9571 - 531ms/epoch - 88ms/step
# Epoch 137/150
# 6/6 - 1s - loss: 0.0623 - mean_absolute_error: 0.0623 - rmse: 0.0690 - val_loss: 6.9326 - val_mean_absolute_error: 6.9326 - val_rmse: 6.9584 - 528ms/epoch - 88ms/step
# Epoch 138/150
# 6/6 - 1s - loss: 0.0620 - mean_absolute_error: 0.0620 - rmse: 0.0681 - val_loss: 6.9307 - val_mean_absolute_error: 6.9307 - val_rmse: 6.9577 - 517ms/epoch - 86ms/step
# Epoch 139/150
# 6/6 - 1s - loss: 0.0616 - mean_absolute_error: 0.0616 - rmse: 0.0679 - val_loss: 6.9413 - val_mean_absolute_error: 6.9413 - val_rmse: 6.9689 - 543ms/epoch - 91ms/step
# Epoch 140/150
# 6/6 - 1s - loss: 0.0613 - mean_absolute_error: 0.0613 - rmse: 0.0673 - val_loss: 6.9374 - val_mean_absolute_error: 6.9374 - val_rmse: 6.9647 - 549ms/epoch - 91ms/step
# Epoch 141/150
# 6/6 - 1s - loss: 0.0602 - mean_absolute_error: 0.0602 - rmse: 0.0663 - val_loss: 6.9407 - val_mean_absolute_error: 6.9407 - val_rmse: 6.9673 - 534ms/epoch - 89ms/step
# Epoch 142/150
# 6/6 - 1s - loss: 0.0603 - mean_absolute_error: 0.0603 - rmse: 0.0663 - val_loss: 6.9337 - val_mean_absolute_error: 6.9337 - val_rmse: 6.9618 - 517ms/epoch - 86ms/step
# Epoch 143/150
# 6/6 - 1s - loss: 0.0600 - mean_absolute_error: 0.0600 - rmse: 0.0663 - val_loss: 6.9479 - val_mean_absolute_error: 6.9479 - val_rmse: 6.9750 - 555ms/epoch - 93ms/step
# Epoch 144/150
# 6/6 - 1s - loss: 0.0620 - mean_absolute_error: 0.0620 - rmse: 0.0678 - val_loss: 6.9260 - val_mean_absolute_error: 6.9260 - val_rmse: 6.9541 - 581ms/epoch - 97ms/step
# Epoch 145/150
# 6/6 - 1s - loss: 0.0707 - mean_absolute_error: 0.0707 - rmse: 0.0772 - val_loss: 6.9284 - val_mean_absolute_error: 6.9284 - val_rmse: 6.9587 - 679ms/epoch - 113ms/step
# Epoch 146/150
# 6/6 - 1s - loss: 0.0640 - mean_absolute_error: 0.0640 - rmse: 0.0701 - val_loss: 6.9276 - val_mean_absolute_error: 6.9276 - val_rmse: 6.9587 - 622ms/epoch - 104ms/step
# Epoch 147/150
# 6/6 - 1s - loss: 0.0751 - mean_absolute_error: 0.0751 - rmse: 0.0820 - val_loss: 6.8858 - val_mean_absolute_error: 6.8858 - val_rmse: 6.9159 - 592ms/epoch - 99ms/step
# Epoch 148/150
# 6/6 - 1s - loss: 0.0713 - mean_absolute_error: 0.0713 - rmse: 0.0777 - val_loss: 6.8076 - val_mean_absolute_error: 6.8076 - val_rmse: 6.8446 - 574ms/epoch - 96ms/step
# Epoch 149/150
# 6/6 - 1s - loss: 0.0744 - mean_absolute_error: 0.0744 - rmse: 0.0817 - val_loss: 6.7427 - val_mean_absolute_error: 6.7427 - val_rmse: 6.7795 - 587ms/epoch - 98ms/step
# Epoch 150/150
# 6/6 - 1s - loss: 0.0697 - mean_absolute_error: 0.0697 - rmse: 0.0766 - val_loss: 6.7446 - val_mean_absolute_error: 6.7446 - val_rmse: 6.7831 - 579ms/epoch - 96ms/step
# Total execute making report :  0.03
# 2023-06-06 22:34:22.491670

# %%
# %load_ext tensorboard

# %tensorboard --logdir logs/fit --host 0.0.0.0

# %%
# Evaluate the model on the test data using `evaluate`
#https://www.tensorflow.org/guide/keras/train_and_evaluate
print("Evaluate on test data")
results = model.evaluate(x_test, y_test, batch_size=batch_size)
print("test loss, test acc:", results)
# Out:
# Evaluate on test data
# 57/57 [==============================] - 1s 8ms/step - loss: 6.7446 - mean_absolute_error: 6.7446 - rmse: 6.7831
# test loss, test acc: [6.7445902824401855, 6.7445902824401855, 6.783053874969482]

# %%
print("List Metrics")
for key in history.history.keys():
    print(key)
# Out:
# List Metrics
# loss
# mean_absolute_error
# rmse
# val_loss
# val_mean_absolute_error
# val_rmse

# %%
# Plot training & validation loss values
fig, ax = plt.subplots(figsize=(10, 5), sharex=True)
plt.plot(history.history["loss"])
plt.title("Model loss")
plt.ylabel("Loss")
plt.xlabel("Epoch")
ax.xaxis.set_major_locator(plt.MaxNLocator(epochs))
plt.legend(["Train"], loc="upper left")
plt.grid()
plt.show()

# %%
plt.plot(history.history['loss'], label='train')
plt.plot(history.history['val_loss'], label='test')
plt.legend()
plt.show()

# %%
plt.title(main_obj_metric)
plt.plot(history.history[main_obj_metric], label='train')
plt.plot(history.history[f'val_{main_obj_metric}'], label='test')
plt.legend()
plt.show()

# %%
plt.title(option_obj_metric)
plt.plot(history.history[option_obj_metric], label='train')
plt.plot(history.history[f'val_{option_obj_metric}'], label='test')
plt.legend()
plt.show()

# %%
# import shap

# we use the first 100 training examples as our background dataset to integrate over
# explainer = shap.DeepExplainer(model, x_train)
# shap_values = explainer.shap_values(x_test)

# %% [markdown]
# # Step #5 Evaluate Model Performance

# %%
# Get the predicted values
y_pred_scaled = model.predict(x_test)
print(y_pred_scaled.shape)

# Unscale the predicted values
y_pred = scaler_pred.inverse_transform(y_pred_scaled)
y_test_unscaled = scaler_pred.inverse_transform(y_test).reshape(-1, output_sequence_length)
print(y_pred.shape)
print(y_test_unscaled.shape)
# Out:
# 57/57 [==============================] - 1s 7ms/step
# (1807, 5)
# (1807, 5)
# (1807, 5)

# %%
RMSE = math.sqrt( mean_squared_error(y_test_unscaled, y_pred))
print(f'Root MEAN Square Error(RMSE): {np.round(RMSE, 2)}')

# Mean Absolute Error (MAE)
MAE = mean_absolute_error(y_test_unscaled, y_pred)
print(f'Mean Absolute Error (MAE): {np.round(MAE, 2)}')


# Mean Absolute Error (MAE)
MAE = mean_absolute_error(y_test_unscaled, y_pred)
print(f'Median Absolute Error (MAE): {np.round(MAE, 2)}')

# Mean Absolute Percentage Error (MAPE)
MAPE = np.mean((np.abs(np.subtract(y_test_unscaled, y_pred)/ y_test_unscaled))) * 100
print(f'Mean Absolute Percentage Error (MAPE): {np.round(MAPE, 2)} %')

# Median Absolute Percentage Error (MDAPE)
MDAPE = np.median((np.abs(np.subtract(y_test_unscaled, y_pred)/ y_test_unscaled)) ) * 100
print(f'Median Absolute Percentage Error (MDAPE): {np.round(MDAPE, 2)} %')
# Out:
# Root MEAN Square Error(RMSE): 101.1
# Mean Absolute Error (MAE): 69.0
# Median Absolute Error (MAE): 69.0
# Mean Absolute Percentage Error (MAPE): 23.99 %
# Median Absolute Percentage Error (MDAPE): 17.38 %

# %% [markdown]
# # Plot Multiple Forcast (Most Complex Step)

# %%
def prepare_df(i, x, y, y_pred_unscaled):
    # Undo the scaling on x, reshape the testset into a one-dimensional array, so that it fits to the pred scaler
    x_test_unscaled_df = pd.DataFrame(scaler_pred.inverse_transform((x[i]))[:,index_Close])\
    .rename(columns={0:'x_test'})
    
    y_test_unscaled_df = []
    # Undo the scaling on y
    if type(y) == np.ndarray:
        y_test_unscaled_df = pd.DataFrame(scaler_pred.inverse_transform(y)[i]).rename(columns={0:'y_test'})

    # Create a dataframe for the y_pred at position i, y_pred is already unscaled
    y_pred_df = pd.DataFrame(y_pred_unscaled[i]).rename(columns={0:'y_pred'})
    return x_test_unscaled_df, y_pred_df, y_test_unscaled_df


def plot_multi_test_forecast(x_test_unscaled_df, y_test_unscaled_df, y_pred_df, title): 
    # Package y_pred_unscaled and y_test_unscaled into a dataframe with columns pred and true   
    if type(y_test_unscaled_df) == pd.core.frame.DataFrame:
        df_merge = y_pred_df.join(y_test_unscaled_df, how='left')
    else:
        df_merge = y_pred_df.copy()
    
    # Merge the dataframes 
    df_merge_ = pd.concat([x_test_unscaled_df, df_merge]).reset_index(drop=True)
    
    # Plot the linecharts
    fig, ax = plt.subplots(figsize=(20, 8))
    plt.title(title, fontsize=12)
    ax.set(ylabel = stockname + "_stock_price_quotes")
    sns.lineplot(data = df_merge_, linewidth=2.0, ax=ax)

# %%
# Creates a linechart for a specific test batch_number and corresponding test predictions

x_test_unscaled_df, y_pred_df, y_test_unscaled_df = prepare_df(i, x_test, y_test, y_pred)
title = f"Predictions vs y_test - test batch number {input_sequence_length}"
plot_multi_test_forecast(x_test_unscaled_df, y_test_unscaled_df, y_pred_df, title)

# %% [markdown]
# # Step #6 Create a new Forecast

# %%
x_test_latest_batch = np_scaled[-(input_sequence_length+1):-1,:].reshape(1,input_sequence_length,len(feature_cols))
print(f"{x_test_latest_batch.shape} is the latest input batch from the test dataset, which is contains the price values for the last {input_sequence_length} trading days")

    
x_test_latest_batch
# Out:
# (1, 30, 1) is the latest input batch from the test dataset, which is contains the price values for the last 30 trading days
# array([[[17.44086022],
#         [17.52883675],
#         [17.6001955 ],
#         [17.60703812],
#         [17.68426197],
#         [17.79863148],
#         [17.85826002],
#         [17.83284457],
#         [17.77321603],
#         [17.95210166],
#         [18.10557185],
#         [18.20918866],
#         [18.20723363],
#         [18.09970674],
#         [17.99120235],
#         [17.96187683],
#         [17.90518084],
#         [17.92179863],
#         [17.99022483],
#         [18.00782014],
#         [17.8514174 ],
#         [17.67644184],
#         [17.45356794],
#         [17.26686217],
#         [17.18475073],
#         [16.99804497],
#         [16.85532747],
#         [16.67253177],
#         [16.46041056],
#         [16.3998045 ]]])

# %%
y_pred_scaled = model.predict(x_test_latest_batch)
y_pred_unscaled = scaler_pred.inverse_transform(y_pred_scaled)
print(f"Predict on the inverse transformed batch {y_pred_unscaled.shape}")
print(y_pred_unscaled)
# Out:
# 1/1 [==============================] - 0s 50ms/step
# Predict on the inverse transformed batch (1, 5)
# [[169.28288 165.03888 155.10576 159.15308 151.90054]]

# %%
print("Prepare the data and plot the input data and the predictions")
x_test_unscaled_df, y_test_unscaled_df, _ = prepare_df(0, x_test_latest_batch, '', y_pred_unscaled)
print(f"X-Test= {x_test_unscaled_df.shape}")
print(f"Y-Test= {y_test_unscaled_df.shape}")

# print(x_test_unscaled_df.tail(len(y_test_unscaled_df)))
# print(y_test_unscaled_df.tail(len(y_test_unscaled_df)))
# Out:
# Prepare the data and plot the input data and the predictions
# X-Test= (30, 1)
# Y-Test= (5, 1)

# %%
plot_multi_test_forecast(x_test_unscaled_df, '',y_test_unscaled_df, "x_new Vs. y_new_pred")
